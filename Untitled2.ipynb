# %%
import pickle as pk

# %%
with open("weather_cache.pkl", "rb") as f:
    data = pk.load(f)

# %%
data
# Out:
# {Timestamp('2019-03-18 16:00:00'): {'time': 1552939200,
#   'summary': 'Clear',
#   'icon': 'clear-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 55.39,
#   'apparentTemperature': 55.39,
#   'dewPoint': 12.03,
#   'humidity': 0.18,
#   'pressure': 1025.42,
#   'windSpeed': 7.35,
#   'windGust': 19.23,
#   'windBearing': 348,
#   'cloudCover': 0,
#   'uvIndex': 5,
#   'visibility': 5.53},
#  Timestamp('2019-03-18 16:05:00'): {'time': 1552939500,
#   'summary': 'Clear',
#   'icon': 'clear-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 55.43,
#   'apparentTemperature': 55.43,
#   'dewPoint': 11.91,
#   'humidity': 0.17,
#   'pressure': 1025.38,
#   'windSpeed': 7.58,
#   'windGust': 19.2,
#   'windBearing': 349,
#   'cloudCover': 0,
#   'uvIndex': 5,
#   'visibility': 5.53},
#  Timestamp('2019-03-18 16:10:00'): {'time': 1552939800,
#   'summary': 'Clear',
#   'icon': 'clear-day',
#   'precipIntensity': 0,
# ...
